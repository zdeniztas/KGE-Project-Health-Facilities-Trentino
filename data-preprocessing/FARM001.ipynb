# %%
import pandas as pd

# %%
# Load the data
df = pd.read_csv('FARM001.csv')

# Display the first few rows
df.head()
# Out:
#    COD_FARMACIA_OD  COD_FARMACIA  \
# 0  FAR042101004054          4054
# 1  FAR042101004162          4162
# 2  FAR042101004163          4163
# 3  FAR042101004164          4164
# 4  FAR042101004165          4165
#
#                                             FARMACIA         IVA    CAP  \
# 0                                  SILVESTRI LUCIANA   673580221  38028
# 1  FARMACIA GMG S.A.S. DEI DOTTORI RAVAGNANI CHIA...  2400290223  38061
# 2                       FRANZELLIN VITTORIO E C. SNC  2209460225  38061
# 3                    BETTINAZZI - R. & T. PHARMA SNC  2018300224  38062
# 4                   FAMIGLIA COOPERATIVA VALLAGARINA   106510225  38063
#
#    COD_COMUNE COMUNE FRAZIONE COD_PROVINCIA PROVINCIA  COD_REGIONE  \
# 0       22152  REVO'        -            TN    TRENTO           42
# 1       22001    ALA        -            TN    TRENTO           42
# 2       22001    ALA        -            TN    TRENTO           42
# 3       22006   ARCO        -            TN    TRENTO           42
# 4       22007   AVIO        -            TN    TRENTO           42
#
#                REGIONE DATA_INIZIO            INDIRIZZO  TIPOLOGIA  \
# 0  PROV. AUTON. TRENTO  2005-01-01  VIA J. A. MAFFEI, 8  ORDINARIA
# 1  PROV. AUTON. TRENTO  2017-07-01  VIA DELLA ROGGIA, 9  ORDINARIA
# 2  PROV. AUTON. TRENTO  2011-09-01     VIA SEGANTINI, 1  ORDINARIA
# 3  PROV. AUTON. TRENTO  2009-09-01        VIA GALAS, 49  ORDINARIA
# 4  PROV. AUTON. TRENTO  2005-01-01       PIAZZA ROMA, 6  ORDINARIA
#
#        LATITUDINE_P     LONGITUDINE_P      LATITUDINE_V     LONGITUDINE_V
# 0  46.4123540693265  11.0520541954953  46,4123540693265  11,0520541954953
# 1  45.7590051426327  11.0026564100186  45,7590051426327  11,0026564100186
# 2  45.7479086521251  11.0414606774668  45,7479086521251  11,0414606774668
# 3  45.9304227931688  10.9070021739945  45,9304227931688  10,9070021739945
# 4  45.7321595956525  10.9198632803229  45,7321595956525  10,9198632803229

# %%
# Check for duplicates
duplicates = df.duplicated()
print("Number of duplicate rows:", duplicates.sum())

# Step 1: Remove duplicates
df = df.drop_duplicates()
# Out:
# Number of duplicate rows: 0

# %%
# Step 2: Check and convert data types
# - Check columns with postal codes, VAT numbers, etc., and ensure they are in the right format
df['COD_FARMACIA'] = df['COD_FARMACIA'].astype(str)   # Pharmacy code as string if it's an identifier
df['CAP'] = df['CAP'].astype(str)                     # Postal codes as string
df['IVA'] = df['IVA'].astype(str)                     # VAT numbers as string

# %%
# Step 3: Standardize text data for pharmacy names
df['FARMACIA'] = df['FARMACIA'].str.upper()

# %%
# Step 4: Convert coordinates to floats, handling non-numeric values
# Replace non-numeric entries like '-' with NaN, then convert to float

# Convert LATITUDINE_P
df['LATITUDINE_P'] = pd.to_numeric(df['LATITUDINE_P'].str.replace(',', '.'), errors='coerce')

# Convert LONGITUDINE_P
df['LONGITUDINE_P'] = pd.to_numeric(df['LONGITUDINE_P'].str.replace(',', '.'), errors='coerce')

# Convert LATITUDINE_V
df['LATITUDINE_V'] = pd.to_numeric(df['LATITUDINE_V'].str.replace(',', '.'), errors='coerce')

# Convert LONGITUDINE_V
df['LONGITUDINE_V'] = pd.to_numeric(df['LONGITUDINE_V'].str.replace(',', '.'), errors='coerce')

# %%
print("Missing values per column:\n", df.isnull().sum())

# Option 1: Drop rows with NaN in coordinates
#df = df.dropna(subset=['LATITUDINE_P', 'LONGITUDINE_P', 'LATITUDINE_V', 'LONGITUDINE_V'])

# Option 2: Fill NaN values with a default value (e.g., 0.0)
# df[['LATITUDINE_P', 'LONGITUDINE_P', 'LATITUDINE_V', 'LONGITUDINE_V']] = df[['LATITUDINE_P', 'LONGITUDINE_P', 'LATITUDINE_V', 'LONGITUDINE_V']].fillna(0.0)
# Out:
# Missing values per column:
#  COD_FARMACIA_OD    0
# COD_FARMACIA       0
# FARMACIA           0
# IVA                0
# CAP                0
# COD_COMUNE         0
# COMUNE             0
# FRAZIONE           0
# COD_PROVINCIA      0
# PROVINCIA          0
# COD_REGIONE        0
# REGIONE            0
# DATA_INIZIO        0
# INDIRIZZO          0
# TIPOLOGIA          0
# LATITUDINE_P       9
# LONGITUDINE_P      9
# LATITUDINE_V       9
# LONGITUDINE_V      9
# dtype: int64

# %%
# Step 5: Save the cleaned data to a new CSV file
#df.to_csv('FARM001_cleaned.csv', index=False)

#print("Cleaning and standardization for FARM001.csv is complete!")
