# %%
import pandas as pd

# %%
# Load the data
df = pd.read_csv('PARAFARM001.csv')

df.head()
# Out:
#   COD_PARAFARMACIA_OD  COD_PARAFARMACIA  \
# 0     PFA042101002507              2507
# 1     PFA042101002508              2508
# 2     PFA042101003394              3394
# 3     PFA042101003686              3686
# 4     PFA042101003915              3915
#
#                                         PARAFARMACIA         IVA    CAP  \
# 0         COOP SUPERSTORE CENTRO COMM.DIR.TRENTO SUD  1542000227  38100
# 1                          COOP SUPERSTORE MILLENIUM  1542000227  38068
# 2                                ERBORISTERIA ANCUSA  1457730222  38057
# 3  ARS MEDICA DI LAURA BALDUCCI & LORENZA VENTURA...  1534610223  38086
# 4               PARAFARMACIA DOTT.SSA SITTONI ANGELA  2037520224  38057
#
#    COD_COMUNE             COMUNE                     INDIRIZZO FRAZIONE  \
# 0       22205             TRENTO  VIA DE GASPERI 1-11-12-13-17        -
# 1       22161           ROVERETO              VIA DEL GARDA 95        -
# 2       22139  PERGINE VALSUGANA           VIA REGENSBURGER 43        -
# 3       22143            PINZOLO                VIA MARCONI 20        -
# 4       22139  PERGINE VALSUGANA          VIA 3 NOVEMBRE NR. 1        -
#
#   COD_PROVINCIA PROVINCIA  COD_REGIONE              REGIONE DATA_INIZIO  \
# 0            TN    TRENTO           42  PROV. AUTON. TRENTO  2007-01-01
# 1            TN    TRENTO           42  PROV. AUTON. TRENTO  2007-01-01
# 2            TN    TRENTO           42  PROV. AUTON. TRENTO  2007-06-01
# 3            TN    TRENTO           42  PROV. AUTON. TRENTO  2007-08-01
# 4            TN    TRENTO           42  PROV. AUTON. TRENTO  2007-09-01
#
#    LATITUDINE_P  LONGITUDINE_P      LATITUDINE_V     LONGITUDINE_V
# 0     46.148630      11.095040          46,14863        11,0950399
# 1     45.872599      11.021258  45,8725985975744   11,021257749762
# 2     46.070266      11.237677  46,0702663118121  11,2376773447364
# 3     46.159056      10.763246  46,1590562564702  10,7632459687159
# 4     46.060829      11.241801         46,060829         11,241801

# %%
# Step 1: Remove duplicates
df = df.drop_duplicates()

# %%
# Step 2: Check and convert data types
# Convert 'COD_PARAFARMACIA' and 'CAP' (postal code) to strings since they are identifiers
df['COD_PARAFARMACIA'] = df['COD_PARAFARMACIA'].astype(str)
df['CAP'] = df['CAP'].astype(str)
df['IVA'] = df['IVA'].astype(str)  # VAT number also as string

# %%
# Step 3: Standardize text data
# Convert 'PARAFARMACIA' (name) and 'COMUNE' (city) to uppercase for consistency
df['PARAFARMACIA'] = df['PARAFARMACIA'].str.upper()
df['COMUNE'] = df['COMUNE'].str.upper()

# %%
# Step 4: Convert coordinates to floats, handling non-numeric values
# Convert LATITUDINE_P, LONGITUDINE_P, LATITUDINE_V, and LONGITUDINE_V columns to float
df['LATITUDINE_P'] = pd.to_numeric(df['LATITUDINE_P'].astype(str).str.replace(',', '.'), errors='coerce')
df['LONGITUDINE_P'] = pd.to_numeric(df['LONGITUDINE_P'].astype(str).str.replace(',', '.'), errors='coerce')
df['LATITUDINE_V'] = pd.to_numeric(df['LATITUDINE_V'].astype(str).str.replace(',', '.'), errors='coerce')
df['LONGITUDINE_V'] = pd.to_numeric(df['LONGITUDINE_V'].astype(str).str.replace(',', '.'), errors='coerce')

# %%
# Step 5: Handle missing or NaN values in coordinates
# Optionally, drop rows with NaN in coordinate columns if critical
print("Missing values per column:\n", df.isnull().sum())

#df = df.dropna(subset=['LATITUDINE_P', 'LONGITUDINE_P', 'LATITUDINE_V', 'LONGITUDINE_V'])
# Out:
# Missing values per column:
#  COD_PARAFARMACIA_OD    0
# COD_PARAFARMACIA       0
# PARAFARMACIA           0
# IVA                    0
# CAP                    0
# COD_COMUNE             0
# COMUNE                 0
# INDIRIZZO              0
# FRAZIONE               0
# COD_PROVINCIA          0
# PROVINCIA              0
# COD_REGIONE            0
# REGIONE                0
# DATA_INIZIO            0
# LATITUDINE_P           0
# LONGITUDINE_P          0
# LATITUDINE_V           0
# LONGITUDINE_V          0
# dtype: int64

# %%
# Drop the specified columns
#columns_to_remove = ['COD_PARAFARMACIA_OD', 'COD_PARAFARMACIA']
#df = df.drop(columns=columns_to_remove)

# %%
# Step 6: Save the cleaned data to a new CSV file
#df.to_csv('PARAFARM001_cleaned.csv', index=False)

print("Cleaning and standardization for PARAFARM001.csv is complete!")
# Out:
# Cleaning and standardization for PARAFARM001.csv is complete!
